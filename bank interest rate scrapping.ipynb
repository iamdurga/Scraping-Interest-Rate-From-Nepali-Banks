# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from bs4 import BeautifulSoup as BS
import requests
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# # Kamana Sewa Bikas bank 1

# %%
url = "https://www.kamanasewabank.com/interest-rates"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
"""
* a dictionary for a bank
* name a key of it as table name, value as dictionary {head: value}
* i.e { deposit:{
  S.N.: [1],
  Saving Deposit: [Mahila Bachat],
},
Loan:{
  S.N.: [1],
  Interest Name: [Student],

}

}
"""
kamana_dict = {}
kamana_intrst = []
table = soup.find("table")
for table in soup.findAll("table"):
  # headers = [str(th.text.strip()) for th in table.find("thead").findAll("th")]
  # # kamana_dict["Deposit"] = {}

  # tmp_dict = {head:[] for head in headers}

  # # table.find("tr").text

  # # lambda fxn to clean each word
  # stripper = lambda  s: " ".join([ss.strip() for ss in s.split(" ")])

  # for tr in table.findAll("tr")[1:]:
  #   col_data = [stripper(td.text) for td in tr.findAll("td")]
  #   for h, c in zip(headers, col_data):
  #     tmp_dict[h].append(c)
  
  df = pd.read_html(str(table))[0]
  kamana_intrst.append(df)

  # print(col_data)
  # break
# tmp_dict, headers
# kamana_dict["deposit"] = tmp_dict
kamana_intrst
# Out:
# [    S.N.  ...       PAYMENT ON
#  0      1  ...  Quarterly Basis
#  1      2  ...  Quarterly Basis
#  2      3  ...  Quarterly Basis
#  3      4  ...  Quarterly Basis
#  4      5  ...  Quarterly Basis
#  5      6  ...  Quarterly Basis
#  6      7  ...  Quarterly Basis
#  7      8  ...  Quarterly Basis
#  8      9  ...  Quarterly Basis
#  9     10  ...  Quarterly Basis
#  10    11  ...  Quarterly Basis
#  11    12  ...  Quarterly Basis
#  12    13  ...  Quarterly Basis
#  13    14  ...  Quarterly Basis
#  14    15  ...  Quarterly Basis
#  15    16  ...  Quarterly Basis
#  16    17  ...  Quarterly Basis
#
#  [17 rows x 5 columns],     S.N.  ...                           PAYMENT ON
#  0      1  ...                                  NaN
#  1      1  ...  Monthly or Quarterly or at Maturity
#  2      1  ...  Monthly or Quarterly or at Maturity
#  3      1  ...  Monthly or Quarterly or at Maturity
#  4      1  ...  Monthly or Quarterly or at Maturity
# ...

# %%
for i, df in enumerate(kamana_intrst):
  df.to_csv(f"kamana{i}.csv")
kamana_intrst[0] # Saving Deposit, Fixed Deposit, Recurring Deposit, Loan, base rate
# Out:
#     S.N.  ...       PAYMENT ON
# 0      1  ...  Quarterly Basis
# 1      2  ...  Quarterly Basis
# 2      3  ...  Quarterly Basis
# 3      4  ...  Quarterly Basis
# 4      5  ...  Quarterly Basis
# 5      6  ...  Quarterly Basis
# 6      7  ...  Quarterly Basis
# 7      8  ...  Quarterly Basis
# 8      9  ...  Quarterly Basis
# 9     10  ...  Quarterly Basis
# 10    11  ...  Quarterly Basis
# 11    12  ...  Quarterly Basis
# 12    13  ...  Quarterly Basis
# 13    14  ...  Quarterly Basis
# 14    15  ...  Quarterly Basis
# 15    16  ...  Quarterly Basis
# 16    17  ...  Quarterly Basis
#
# [17 rows x 5 columns]

# %%
df = pd.read_html(str(table))[0]
df
# Out:
#       SN                      As on quarter end Base Rate
# 0    1.0    Base Rate (BR) as on Poush end 2077     9.05%
# 1    2.0   Base Rate (BR) as on Ashwin end 2077     9.28%
# 2    3.0    Base Rate (BR) as on Ashad end 2077    10.55%
# 3    4.0  Base Rate (BR) as on Chaitra end 2076    11.79%
# 4    5.0    Base Rate (BR) as on Paush end 2076    11.86%
# 5    6.0   Base Rate (BR) as on Ashwin end 2076    11.86%
# 6    7.0   ​Base Rate (BR) as on Ashad End 2076    11.59%
# 7    8.0  Base Rate (BR) as on Chaitra End 2075    11.65%
# 8    9.0    Base Rate (BR) as on Paush End 2075    11.59%
# 9   10.0   Base Rate (BR) as on Ashwin End 2075    11.83%
# 10   NaN                                    NaN       NaN
# 11  11.0    Base Rate (BR) as on Ashad End 2075    12.58%
# 12  12.0  Base Rate (BR) as on Chaitra End 2074    12.17%
# 13  13.0   ​Base Rate (BR) as on Paush End 2074    11.92%
# 14  14.0    Base Rate (BR) as on Ashad End 2074    11.71%

# %% [markdown]
# # Muktinath Bikas Bank 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from bs4 import BeautifulSoup as BS
import requests
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
url = "https://www.muktinathbank.com.np/interest-rates"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
muktinath_intrst = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  muktinath_intrst.append(df)

# %%
muktinath_intrst[2] # hard code the table name
# Out:
#                                          PRODUCT                             FLOATING INTEREST BAND
# 0                               1. Business Loan                    Base Rate + Premium up to 4.50%
# 1                            2. Agriculture Loan                    Base Rate + Premium up to 4.50%
# 2     3. Home Loan (new construction & purchase)                    Base Rate + Premium up to 4.50%
# 3                            4. Home Equity Loan                    Base Rate + Premium up to 4.50%
# 4                                   5. Auto Loan                    Base Rate + Premium up to 5.00%
# 5                      6. Hirepurchase Loan(new)                    Base Rate + Premium up to 5.00%
# 6                      7. Hirepurchase Loan(old)                    Base Rate + Premium up to 5.00%
# 7                            8. Real Estate Loan                    Base Rate + Premium up to 5.00%
# ...

# %% [markdown]
# # NIC Asia Bank 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from bs4 import BeautifulSoup as BS
import requests
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
url = "https://www.nicasiabank.com/interest-rates"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
NICasia_intrst = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  NICasia_intrst.append(df)

# %%
NICasia_intrst[0]
# Out:
#     S.N  ... Interest Rate(%p.a)
# 0     1  ...               2.10%
# 1     2  ...               2.10%
# 2     3  ...               2.10%
# 3     4  ...               2.10%
# 4     5  ...               2.10%
# ..  ...  ...                 ...
# 88   89  ...               3.50%
# 89   90  ...               3.50%
# 90   91  ...               3.50%
# 91   92  ...               3.50%
# 92   93  ...               3.50%
#
# [93 rows x 4 columns]

# %% [markdown]
# # Investment Bank 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from bs4 import BeautifulSoup as BS
import requests
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
url = "https://nibl.com.np/personal-banking/rates-and-fees/interest-rates"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
Invest_intrest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  Invest_intrest.append(df)

# %%
Invest_intrest[0]
# Out:
#           0          1          2                3                          4
# 0   2074-75     Period  Base Rate  Interest Spread                    Remarks
# 1   2074-75  Quarter 1      8.91%            4.32%                        NaN
# 2   2074-75  Quarter 2      9.00%            4.05%                        NaN
# 3   2074-75  Quarter 3      9.12%            4.28%                        NaN
# 4   2074-75  Quarter 4      9.02%            4.59%                        NaN
# 5       NaN        NaN        NaN              NaN                        NaN
# 6   2075-76     Period  Base Rate  Interest Spread                    Remarks
# 7   2075-76  Quarter 1      9.03%            4.53%                        NaN
# 8   2075-76  Quarter 2      8.96%            4.24%                        NaN
# 9   2075-76  Quarter 3      8.54%            4.24%                        NaN
# 10  2075-76  Quarter 4      8.33%            4.38%                        NaN
# ...

# %% [markdown]
# # Civil Bank 5

# %%
url = "https://www.civilbank.com.np/financial-information/interest-rates"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
civil_intrest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  civil_intrest.append(df)

# %%
civil_intrest[0]

# %% [markdown]
# # Himalayan Bank 6

# %%
url = "https://www.himalayanbank.com/en/rates/deposit-products-rate"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
himalayan_intrest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  himalayan_intrest.append(df)

# %%
himalayan_intrest[0]
# Out:
#                         Savings Deposit  %Per Annum
# 0                  LCY Savings - Normal        2.00
# 1                   LCY Savings - Himal        3.00
# 2                 LCY Savings - Bishesh        3.50
# 3               Premium Savings Account        3.50
# 4         Super Premium Savings Account        3.75
# 5                 Shareholder's Savings        3.25
# 6                   Himal Remit Savings        3.50
# 7                        Family Savings        3.50
# 8              Mero Pahilo Bachat Khata        3.00
# 9               Special Payroll Account        3.50
# 10                      HBL Nari Bachat        3.50
# 11              Subidha Savings Account        4.00
# 12  Exclusive Privilege Savings Account        4.00
# 13              Jeevan Surakchya Bachat        3.00
# 14                 LCY Savings - Normal        2.00
# 15                  LCY Savings - Himal        3.00
# 16                LCY Savings - Bishesh        3.50
# ...

# %% [markdown]
# # Kumari Bank 7

# %%
url = "https://www.kumaribank.com/interest-rate-deposits"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
kumari_intrest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  kumari_intrest.append(df)

# %%
kumari_intrest[0]

# %% [markdown]
# # Sanima Bikas Bank 8

# %%
url = "https://www.sanimabank.com/interest-rate"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
sanima_intrest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  sanima_intrest.append(df)

# %%
sanima_intrest[0]
# Out:
#    Unnamed: 0_level_0  ...                            Interest Payment
#    Unnamed: 0_level_1  ...                  Interest Payment Frequency
#    Unnamed: 0_level_2  ...                          Unnamed: 5_level_2
#    Unnamed: 0_level_3  ...                          Unnamed: 5_level_3
#    Unnamed: 0_level_4  ...                          Unnamed: 5_level_4
#    Unnamed: 0_level_5  ...                          Unnamed: 5_level_5
#    Unnamed: 0_level_6  ...                          Unnamed: 5_level_6
#    Unnamed: 0_level_7  ...                          Unnamed: 5_level_7
#    Unnamed: 0_level_8  ...                          Unnamed: 5_level_8
#    Unnamed: 0_level_9  ...                          Unnamed: 5_level_9
# 0                 NaN  ...                                   Quarterly
# 1                 NaN  ...                                   Quarterly
# 2                 NaN  ...                                   Quarterly
# ...

# %% [markdown]
# # Garima bikas Bank 9

# %%
url = "https://garimabank.com.np/interest-rates.html"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
banijya_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  banijya_interest.append(df)

# %%
banijya_interest[0]

# %% [markdown]
# # Prime commercial bank 10

# %%
url = "https://www.primebank.com.np/interest/details/78"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
prime_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  prime_interest.append(df)

# %%
prime_interest

# %% [markdown]
# # Himalayan Bank  11

# %%
url = "https://himalayanbank.com/en/rates/deposit-products-rate"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
himalayan_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  himalayan_interest.append(df)

# %%
himalayan_interest

# %% [markdown]
# # Sunrise Bank 12

# %%
url = "https://www.sunrisebank.com.np/interest-rate"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
sunrise_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  sunrise_interest.append(df)

# %%
sunrise_interest

# %% [markdown]
# # Citizen Bank 13

# %%
url = "https://www.ctznbank.com/interest-rate"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
citizen_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  citizen_interest.append(df)

# %%
citizen_interest

# %% [markdown]
# # Everest bank 14

# %%
url = "https://everestbankltd.com/supports/interest-and-rates/interest-rates-deposit/"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
everest_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  everest_interest.append(df)

# %%
everest_interest

# %% [markdown]
# # Agriculture Bank 15

# %%
url = "https://www.agricbank.com/customer-care/financials/current-rates/"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
agricul_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  agricul_interest.append(df)

# %%
agricul_interest

# %% [markdown]
# # Laxmi Bank 16

# %%
url = "https://www.laxmibank.com/rates/interest-rates/"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
laxmi_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  laxmi_interest.append(df)

# %%
laxmi_interest

# %% [markdown]
# # Parbhu Bikas Bank 17

# %%
url = "https://www.prabhubank.com/interest-rates"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
parbhu_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  parbhu_interest.append(df)

# %%
parbhu_interest

# %% [markdown]
# # NMB Bank 18

# %%
url = "https://nmbbanknepal.com/interest-rate"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
parbhu_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  parbhu_interest.append(df)

# %%
parbhu_interest

# %% [markdown]
# # Garima Bank 19

# %%
url = "https://garimabank.com.np/interest-rates.html"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
garima_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  garima_interest.append(df)

# %%
garima_interest

# %% [markdown]
# # Jyoti Bank 20

# %%
url = "https://jbbl.com.np/quick-links/interest-rate"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
jyoti_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  jyoti_interest.append(df)

# %%
jyoti_interest

# %% [markdown]
# # Lumbini Bank 21

# %%
url = "https://www.lumbinibikasbank.com/navigation/interest-rate"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
lumbini_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  lumbini_interest.append(df)

# %%
lumbini_interest

# %% [markdown]
# # Machhapuchre Bank 22

# %%
url = "https://www.machbank.com/interest-rate"

# %%
http = urllib3.PoolManager()
http.addheaders = [('User-agent', 'Mozilla/61.0')]
web_page = http.request('GET', url)
soup = BS(web_page.data, 'html5lib')

# %%
machhapuchre_interest = []
table = soup.find("table")
for table in soup.findAll("table"):
  df = pd.read_html(str(table))[0]
  machhapuchre_interest.append(df)

# %%
machhapuchre_interest
